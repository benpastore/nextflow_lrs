# %%
pip install kagglehub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.0/231.0 kB 7.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%bash
#
# sh kaggle.sh

# %%
import kagglehub

# Download latest version
path = kagglehub.model_download("google/alphagenome/jax/all_folds")

print("Path to model files:", path)
# Out:
# ...
# 100%|██████████| 277/277 [00:00<00:00, 307kB/s]
# ...
#   0%|          | 0.00/2.26k [00:00<?, ?B/s]
#
# 100%|██████████| 2.26k/2.26k [00:00<00:00, 1.26MB/s]
# ...
#   0%|          | 0.00/218k [00:00<?, ?B/s]
# ...
#   0%|          | 0.00/396M [00:00<?, ?B/s]
#
#
#
# 100%|██████████| 75.5k/75.5k [00:00<00:00, 1.32MB/s][A
# ...
#   0%|          | 0.00/146M [00:00<?, ?B/s]
# 100%|██████████| 218k/218k [00:00<00:00, 1.96MB/s]
# ...
# 100%|██████████| 120/120 [00:00<00:00, 135kB/s]
#
#
#
#
#   1%|          | 1.00M/158M [00:00<00:27, 6.06MB/s]
#
#
#   0%|          | 1.00M/396M [00:00<01:09, 5.97MB/s]
#
#   1%|          | 1.00M/146M [00:00<00:28, 5.31MB/s]
#
#
#
#   3%|▎         | 4.00M/158M [00:00<00:09, 17.5MB/s]
#
#
#   3%|▎         | 10.0M/396M [00:00<00:08, 45.2MB/s]
#
#   8%|▊         | 12.0M/146M [00:00<00:02, 50.6MB/s]
#
#
#
#  10%|█         | 16.0M/158M [00:00<00:02, 58.4MB/s]
#
#
#   4%|▍         | 16.0M/396M [00:00<00:08, 46.9MB/s]
#
#  18%|█▊        | 26.0M/146M [00:00<00:01, 86.2MB/s]
#
# ...

# %%
# %%bash
#
# rm -r /users/PAS1473/benpasto1/.cache/kagglehub/models

# %%
# %%bash
#
# ls /users/PAS1473/benpasto1/.cache/kagglehub/models/google/alphagenome/jax/all_folds/1
# Out:
# _CHECKPOINT_METADATA
# d
# manifest.ocdbt
# _METADATA
# ocdbt.process_0
